# %%
# %pip install dash flask explainerdashboard
# Out:
# ...
#   Using cached explainerdashboard-0.4.7-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached dash_auth-2.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached dash_bootstrap_components-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached flask_simplelogin-0.1.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached flask_wtf-1.2.1-py3-none-any.whl.metadata (3.4 kB)
# ...
# Using cached explainerdashboard-0.4.7-py3-none-any.whl (287 kB)
# Using cached dash_bootstrap_components-1.5.0-py3-none-any.whl (221 kB)
# Using cached flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Using cached dash_auth-2.3.0-py3-none-any.whl (14 kB)
# Using cached flask_simplelogin-0.1.2-py3-none-any.whl (7.2 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip freeze > ../requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df_saresp_19 = pd.read_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2019 - DADOS ABERTO.csv', sep=';', decimal=',')
df_saresp_19\
    .loc[df_saresp_19.MUN == 'EMBU-GUACU']\
    .to_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2019 - DADOS ABERTO.csv', sep=';', decimal=',')
    
df_saresp_21 = pd.read_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2021 - DADOS ABERTO.csv', sep=';', decimal=',')
df_saresp_21\
    .loc[df_saresp_21.MUN == 'EMBU-GUACU']\
    .to_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2021 - DADOS ABERTO.csv', sep=';', decimal=',')

df_saresp_22 = pd.read_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2022 - DADOS ABERTO.csv', sep=';', decimal=',')
df_saresp_22\
    .loc[df_saresp_22.MUN == 'EMBU-GUACU']\
    .to_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2022 - DADOS ABERTO.csv', sep=';', decimal=',')
# Out:
# C:\Users\Pehls\AppData\Local\Temp\ipykernel_26356\712205584.py:6: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_saresp_21 = pd.read_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2021 - DADOS ABERTO.csv', sep=';', decimal=',')

# %%
df_saresp_19 = pd.read_csv(r'D:\Cursos\FIAP_pós\gp27_techchallenge_5\data\raw\saresp_rendimento_escolar\MICRODADOS SARESP 2022 - DADOS ABERTO.csv', sep=';', decimal=',')
df_saresp_19.loc[df_saresp_19.MUN == 'EMBU-GUACU']
# Out:
#          CD_ALUNO      NOMEDEP     NomeDepBol  \
# 815      20055504  ESTADUAL-SE  Rede Estadual
# 1243     20330006  ESTADUAL-SE  Rede Estadual
# 4252     21063908  ESTADUAL-SE  Rede Estadual
# 10152    21688670  ESTADUAL-SE  Rede Estadual
# 10395    21718867  ESTADUAL-SE  Rede Estadual
# ...           ...          ...            ...
# 1323977  38447448  ESTADUAL-SE  Rede Estadual
# 1325730  38563879  ESTADUAL-SE  Rede Estadual
# 1329019  38853166  ESTADUAL-SE  Rede Estadual
# 1329752  38877860  ESTADUAL-SE  Rede Estadual
# 1329956  38887957  ESTADUAL-SE  Rede Estadual
#
#                        RegiaoMetropolitana  CDREDE                    DE  \
# 815      Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# 1243     Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# 4252     Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# 10152    Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# ...

# %%
df_saresp_19.loc[df_saresp_19.MUN == 'EMBU-GUACU']
# Out:
#          CD_ALUNO      NOMEDEP     NomeDepBol  \
# 815      20055504  ESTADUAL-SE  Rede Estadual
# 1243     20330006  ESTADUAL-SE  Rede Estadual
# 4252     21063908  ESTADUAL-SE  Rede Estadual
# 10152    21688670  ESTADUAL-SE  Rede Estadual
# 10395    21718867  ESTADUAL-SE  Rede Estadual
# ...           ...          ...            ...
# 1323977  38447448  ESTADUAL-SE  Rede Estadual
# 1325730  38563879  ESTADUAL-SE  Rede Estadual
# 1329019  38853166  ESTADUAL-SE  Rede Estadual
# 1329752  38877860  ESTADUAL-SE  Rede Estadual
# 1329956  38887957  ESTADUAL-SE  Rede Estadual
#
#                        RegiaoMetropolitana  CDREDE                    DE  \
# 815      Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# 1243     Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# 4252     Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# 10152    Região Metropolitana de São Paulo   10702  ITAPECERICA DA SERRA
# ...
